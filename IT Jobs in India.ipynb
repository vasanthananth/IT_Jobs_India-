# %%
import pandas as pd
df = pd.read_csv("IT Jobs.csv")
df
# Out:
#          State Names   Data Science   Web Technology    AI   Cybersecurity   \
# 0      Andhra Pradesh             62              239    30              45
# 1   Arunachal Pradesh            262                2     0               1
# 2               Assam              7               28     4               6
# 3               Bihar             21              169     4              11
# 4        Chhattisgarh             21               75     2               6
# 5                 Goa             18              140    14              21
# 6             Gujarat            434              333   209             294
# 7             Haryana           1547             3359  1079             897
# 8    Himachal Pradesh             13               26     0              13
# 9           Jharkhand             20               43     8              15
# 10          Karnataka           5600             9873  4350            3394
# ...

# %%
import matplotlib.pyplot as plt
df.plot.area(figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %%
 axs = df.plot.line(figsize=(20, 50), subplots=True, marker="o")

# %%
df.head(10)
# Out:
#         State Names   Data Science   Web Technology    AI   Cybersecurity   \
# 0     Andhra Pradesh             62              239    30              45
# 1  Arunachal Pradesh            262                2     0               1
# 2              Assam              7               28     4               6
# 3              Bihar             21              169     4              11
# 4       Chhattisgarh             21               75     2               6
# 5                Goa             18              140    14              21
# 6            Gujarat            434              333   209             294
# 7            Haryana           1547             3359  1079             897
# 8   Himachal Pradesh             13               26     0              13
# 9          Jharkhand             20               43     8              15
#
#    Automation   Cloud   Business / IT Services   IT Networking   R & D
# 0          109     112                      778             357    147
# ...

# %%
df.describe()
# Out:
#        Data Science   Web Technology           AI   Cybersecurity   \
# count      28.000000        28.000000    28.000000       28.000000
# mean      628.250000      1359.678571   399.678571      334.714286
# std      1205.183454      2234.213592   881.122140      759.515433
# min         1.000000         1.000000     0.000000        0.000000
# 25%        20.750000        39.250000     2.000000        3.250000
# 50%       201.500000       294.000000    32.000000       27.000000
# 75%       485.500000      1340.750000   271.500000      200.250000
# max      5600.000000      9873.000000  4350.000000     3394.000000
#
#         Automation         Cloud   Business / IT Services   IT Networking   \
# count     28.000000     28.000000                28.000000       28.000000
# mean    1341.357143   1540.964286              5399.000000       83.678571
# std     2881.469265   3935.271062             10113.837726      236.700163
# ...

# %%
df.iloc[1:8,:]
# Out:
#         State Names   Data Science   Web Technology    AI   Cybersecurity   \
# 1  Arunachal Pradesh            262                2     0               1
# 2              Assam              7               28     4               6
# 3              Bihar             21              169     4              11
# 4       Chhattisgarh             21               75     2               6
# 5                Goa             18              140    14              21
# 6            Gujarat            434              333   209             294
# 7            Haryana           1547             3359  1079             897
#
#    Automation   Cloud   Business / IT Services   IT Networking   R & D
# 1            1       1                       16               0      3
# 2           22      16                      146               0     59
# 3           15      11                      297               0    102
# 4           17      18                      196               0     66
# ...

# %%
df.iloc[:4]
# Out:
#         State Names   Data Science   Web Technology   AI   Cybersecurity   \
# 0     Andhra Pradesh             62              239   30              45
# 1  Arunachal Pradesh            262                2    0               1
# 2              Assam              7               28    4               6
# 3              Bihar             21              169    4              11
#
#    Automation   Cloud   Business / IT Services   IT Networking   R & D
# 0          109     112                      778             357    147
# 1            1       1                       16               0      3
# 2           22      16                      146               0     59
# 3           15      11                      297               0    102

# %%
for row in df.iterrows():
    print (row)
# Out:
# (0, State Names                Andhra Pradesh
# Data Science                           62
# Web Technology                        239
# AI                                     30
# Cybersecurity                          45
# Automation                            109
# Cloud                                 112
# Business / IT Services                778
# IT Networking                         357
# R & D                                 147
# Name: 0, dtype: object)
# (1, State Names                Arunachal Pradesh
# Data Science                             262
# Web Technology                             2
# AI                                         0
# Cybersecurity                              1
# Automation                                 1
# Cloud                                      1
# Business / IT Services                    16
# IT Networking                              0
# R & D                                      3
# Name: 1, dtype: object)
# ...
